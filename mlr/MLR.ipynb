# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars=pd.read_csv("ToyotaCorolla - MLR.csv")
cars
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
cars.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
cars.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
cars.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %% [markdown]
# # NO NULL VALUES

# %% [markdown]
# # Renaming the Columns name

# %%
cars=cars.rename({'Age_08_04':'Age','cc':'CC'},axis=1)
cars.head()
# Out:
#    Price  Age     KM Fuel_Type  HP  Automatic    CC  Doors  Cylinders  Gears  \
# 0  13500   23  46986    Diesel  90          0  2000      3          4      5
# 1  13750   23  72937    Diesel  90          0  2000      3          4      5
# 2  13950   24  41711    Diesel  90          0  2000      3          4      5
# 3  14950   26  48000    Diesel  90          0  2000      3          4      5
# 4  13750   30  38500    Diesel  90          0  2000      3          4      5
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %% [markdown]
# # change the Data types of column

# %%
cars['Fuel_Type']=cars['Fuel_Type'].astype("category")
cars.dtypes
# Out:
# Price           int64
# Age             int64
# KM              int64
# Fuel_Type    category
# HP              int64
# Automatic       int64
# CC              int64
# Doors           int64
# Cylinders       int64
# Gears           int64
# Weight          int64
# dtype: object

# %% [markdown]
# # Find the Duplicate rows and Remove

# %%
cars[cars.duplicated(keep=False)]
# Out:
#      Price  Age     KM Fuel_Type   HP  Automatic    CC  Doors  Cylinders  \
# 112  24950    8  13253    Diesel  116          0  2000      5          4
# 113  24950    8  13253    Diesel  116          0  2000      5          4
#
#      Gears  Weight
# 112      5    1320
# 113      5    1320

# %%
car=cars.drop_duplicates().reset_index()
car.drop(["index"],axis=1,inplace=True)
car.head()
# Out:
#    Price  Age     KM Fuel_Type  HP  Automatic    CC  Doors  Cylinders  Gears  \
# 0  13500   23  46986    Diesel  90          0  2000      3          4      5
# 1  13750   23  72937    Diesel  90          0  2000      3          4      5
# 2  13950   24  41711    Diesel  90          0  2000      3          4      5
# 3  14950   26  48000    Diesel  90          0  2000      3          4      5
# 4  13750   30  38500    Diesel  90          0  2000      3          4      5
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
car.describe()
# Out:
#               Price          Age             KM           HP    Automatic  \
# count   1435.000000  1435.000000    1435.000000  1435.000000  1435.000000
# mean   10720.915679    55.980488   68571.782578   101.491986     0.055749
# std     3608.732978    18.563312   37491.094553    14.981408     0.229517
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63451.000000   110.000000     0.000000
# 75%    11950.000000    70.000000   87041.500000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                  CC        Doors  Cylinders        Gears       Weight
# count   1435.000000  1435.000000     1435.0  1435.000000  1435.000000
# mean    1576.560976     4.032753        4.0     5.026481  1072.287108
# std      424.387533     0.952667        0.0     0.188575    52.251882
# ...

# %% [markdown]
# # Visualizations

# %% [markdown]
# # For Categorical data

# %%
print(car["Fuel_Type"].value_counts())
car["Fuel_Type"].value_counts().plot(kind="bar",width=0.5,color="peru")
# Out:
# Fuel_Type
# Petrol    1264
# Diesel     154
# CNG         17
# Name: count, dtype: int64
# <Axes: xlabel='Fuel_Type'>

# %%
# Most of the cars Fuel_Type is Petrol

# %%
print(car["Automatic"].value_counts())
car["Automatic"].value_counts().plot(kind="bar",width=0.3,color="peru")
# Out:
# Automatic
# 0    1355
# 1      80
# Name: count, dtype: int64
# <Axes: xlabel='Automatic'>

# %%
print(car["Doors"].value_counts())
car["Doors"].value_counts().plot(kind="bar",width=0.5,color="peru")
# Out:
# Doors
# 5    673
# 3    622
# 4    138
# 2      2
# Name: count, dtype: int64
# <Axes: xlabel='Doors'>

# %%
print(car["Cylinders"].value_counts())
car["Cylinders"].value_counts().plot(kind="bar",width=0.1,color="peru")
# Out:
# Cylinders
# 4    1435
# Name: count, dtype: int64
# <Axes: xlabel='Cylinders'>

# %%
car["Gears"].value_counts().plot(kind="bar",width=0.5,color="peru")
print(car["Gears"].value_counts())
# Out:
# Gears
# 5    1389
# 6      43
# 3       2
# 4       1
# Name: count, dtype: int64

# %%
# For Numerical Columns

# %%
car.select_dtypes("int64").hist(figsize=(12,10))
# Out:
# array([[<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Age'}>, <Axes: title={'center': 'KM'}>],
#        [<Axes: title={'center': 'HP'}>,
#         <Axes: title={'center': 'Automatic'}>,
#         <Axes: title={'center': 'CC'}>],
#        [<Axes: title={'center': 'Doors'}>,
#         <Axes: title={'center': 'Cylinders'}>,
#         <Axes: title={'center': 'Gears'}>],
#        [<Axes: title={'center': 'Weight'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# Box plot

# %%
car.select_dtypes("int64").plot(kind="box")
# Out:
# <Axes: >

# %%
sns.pairplot(car)

# %%
car.select_dtypes("int64").corr()
# Out:
#               Price       Age        KM        HP  Automatic        CC  \
# Price      1.000000 -0.876273 -0.569420  0.314134   0.033928  0.124375
# Age       -0.876273  1.000000  0.504575 -0.155293   0.031354 -0.096549
# KM        -0.569420  0.504575  1.000000 -0.332904  -0.082168  0.103822
# HP         0.314134 -0.155293 -0.332904  1.000000   0.013313  0.035207
# Automatic  0.033928  0.031354 -0.082168  0.013313   1.000000  0.066934
# CC         0.124375 -0.096549  0.103822  0.035207   0.066934  1.000000
# Doors      0.183604 -0.146929 -0.035193  0.091803  -0.027492  0.079254
# Cylinders       NaN       NaN       NaN       NaN        NaN       NaN
# Gears      0.063831 -0.005629  0.014890  0.209642  -0.098582  0.014732
# Weight     0.575869 -0.466484 -0.023969  0.087143   0.058499  0.335077
#
#               Doors  Cylinders     Gears    Weight
# Price      0.183604        NaN  0.063831  0.575869
# Age       -0.146929        NaN -0.005629 -0.466484
# ...

# %% [markdown]
# # Price and Age are strongly negatively linear related
# # Price and KM are negatively related
# # Price and Weight are associated each other

# %% [markdown]
# # converting into Dummy Variables

# %%
car1=pd.get_dummies(car,dtype='int64',drop_first=True)
car1
# Out:
#       Price  Age     KM   HP  Automatic    CC  Doors  Cylinders  Gears  \
# 0     13500   23  46986   90          0  2000      3          4      5
# 1     13750   23  72937   90          0  2000      3          4      5
# 2     13950   24  41711   90          0  2000      3          4      5
# 3     14950   26  48000   90          0  2000      3          4      5
# 4     13750   30  38500   90          0  2000      3          4      5
# ...     ...  ...    ...  ...        ...   ...    ...        ...    ...
# 1430   7500   69  20544   86          0  1300      3          4      5
# 1431  10845   72  19000   86          0  1300      3          4      5
# 1432   8500   71  17016   86          0  1300      3          4      5
# 1433   7250   70  16916   86          0  1300      3          4      5
# 1434   6950   76      1  110          0  1600      5          4      5
#
#       Weight  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0       1165                 1                 0
# ...

# %%
x1=car1.drop(columns=['Price'])
y1=car1['Price']
x1.shape
# Out:
# (1435, 11)

# %%
from sklearn.model_selection import train_test_split

# %%
train_x1,test_x1,train_y1,test_y1=train_test_split(x1,y1,test_size=0.2,random_state=11)
print(train_x1.shape,train_y1.shape)
# Out:
# (1148, 11) (1148,)

# %%
import statsmodels.api as sm

# %%
model1=sm.OLS(train_y1,train_x1).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     811.7
# Date:                Sun, 11 Aug 2024   Prob (F-statistic):               0.00
# Time:                        00:42:13   Log-Likelihood:                -9850.6
# No. Observations:                1148   AIC:                         1.972e+04
# Df Residuals:                    1137   BIC:                         1.978e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # here Automatic and Doors are having p value > 0.05

# %%
car2=car1.drop(columns=['Automatic','Doors'])
car2
# Out:
#       Price  Age     KM   HP    CC  Cylinders  Gears  Weight  \
# 0     13500   23  46986   90  2000          4      5    1165
# 1     13750   23  72937   90  2000          4      5    1165
# 2     13950   24  41711   90  2000          4      5    1165
# 3     14950   26  48000   90  2000          4      5    1165
# 4     13750   30  38500   90  2000          4      5    1170
# ...     ...  ...    ...  ...   ...        ...    ...     ...
# 1430   7500   69  20544   86  1300          4      5    1025
# 1431  10845   72  19000   86  1300          4      5    1015
# 1432   8500   71  17016   86  1300          4      5    1015
# 1433   7250   70  16916   86  1300          4      5    1015
# 1434   6950   76      1  110  1600          4      5    1114
#
#       Fuel_Type_Diesel  Fuel_Type_Petrol
# 0                    1                 0
# 1                    1                 0
# 2                    1                 0
# 3                    1                 0
# ...

# %%
x2=car2.drop(columns=['Price'])
y2=car2['Price']

# %%
train_x2,test_x2,train_y2,test_y2=train_test_split(x2,y2,test_size=0.2,random_state=1)
print(train_x2.shape,train_y2.shape)
# Out:
# (1148, 9) (1148,)

# %%
model2=sm.OLS(train_y2,train_x2).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     894.7
# Date:                Sun, 11 Aug 2024   Prob (F-statistic):               0.00
# Time:                        00:42:14   Log-Likelihood:                -9874.8
# No. Observations:                1148   AIC:                         1.977e+04
# Df Residuals:                    1139   BIC:                         1.981e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Here Cyliders has only one Values
# # remove the Drop Column

# %%
car3=car2.drop(columns=['Cylinders'])
car3.head()
# Out:
#    Price  Age     KM  HP    CC  Gears  Weight  Fuel_Type_Diesel  \
# 0  13500   23  46986  90  2000      5    1165                 1
# 1  13750   23  72937  90  2000      5    1165                 1
# 2  13950   24  41711  90  2000      5    1165                 1
# 3  14950   26  48000  90  2000      5    1165                 1
# 4  13750   30  38500  90  2000      5    1170                 1
#
#    Fuel_Type_Petrol
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
x3=car3.drop(columns=['Price'])
y3=car3['Price']

# %%
train_x3,test_x3,train_y3,test_y3=train_test_split(x3,y3,test_size=0.2,random_state=10)
print(train_x3.shape,train_y3.shape)
# Out:
# (1148, 8) (1148,)

# %%
model3=sm.OLS(train_y3,train_x3).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                          1.010e+04
# Date:                Sun, 11 Aug 2024   Prob (F-statistic):                        0.00
# Time:                        00:42:14   Log-Likelihood:                         -9886.3
# No. Observations:                1148   AIC:                                  1.979e+04
# Df Residuals:                    1140   BIC:                                  1.983e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
car4=car3.drop(columns=['CC'])
car4
# Out:
#       Price  Age     KM   HP  Gears  Weight  Fuel_Type_Diesel  \
# 0     13500   23  46986   90      5    1165                 1
# 1     13750   23  72937   90      5    1165                 1
# 2     13950   24  41711   90      5    1165                 1
# 3     14950   26  48000   90      5    1165                 1
# 4     13750   30  38500   90      5    1170                 1
# ...     ...  ...    ...  ...    ...     ...               ...
# 1430   7500   69  20544   86      5    1025                 0
# 1431  10845   72  19000   86      5    1015                 0
# 1432   8500   71  17016   86      5    1015                 0
# 1433   7250   70  16916   86      5    1015                 0
# 1434   6950   76      1  110      5    1114                 0
#
#       Fuel_Type_Petrol
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 1430                 1
# 1431                 1
# ...

# %%
x4=car4.drop(columns=['Price'])
y4=car4['Price']

# %%
train_x4,test_x4,train_y4,test_y4=train_test_split(x4,y4,test_size=0.2,random_state=5)
print(train_x4.shape,train_y4.shape)
# Out:
# (1148, 7) (1148,)

# %%
model4=sm.OLS(train_y4,train_x4).fit()
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                          1.144e+04
# Date:                Sun, 11 Aug 2024   Prob (F-statistic):                        0.00
# Time:                        00:42:14   Log-Likelihood:                         -9904.7
# No. Observations:                1148   AIC:                                  1.982e+04
# Df Residuals:                    1141   BIC:                                  1.986e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Build the model with Entire Data

# %%
X=car4.iloc[:,1:]
Y=car4.iloc[:,0]

# %%
X
# Out:
#       Age     KM   HP  Gears  Weight  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0      23  46986   90      5    1165                 1                 0
# 1      23  72937   90      5    1165                 1                 0
# 2      24  41711   90      5    1165                 1                 0
# 3      26  48000   90      5    1165                 1                 0
# 4      30  38500   90      5    1170                 1                 0
# ...   ...    ...  ...    ...     ...               ...               ...
# 1430   69  20544   86      5    1025                 0                 1
# 1431   72  19000   86      5    1015                 0                 1
# 1432   71  17016   86      5    1015                 0                 1
# 1433   70  16916   86      5    1015                 0                 1
# 1434   76      1  110      5    1114                 0                 1
#
# [1435 rows x 7 columns]

# %%
Y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1430     7500
# 1431    10845
# 1432     8500
# 1433     7250
# 1434     6950
# Name: Price, Length: 1435, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=5)

# %%
Linear=sm.OLS(Y,X).fit()
print(Linear.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                          1.404e+04
# Date:                Sun, 11 Aug 2024   Prob (F-statistic):                        0.00
# Time:                        00:42:14   Log-Likelihood:                         -12383.
# No. Observations:                1435   AIC:                                  2.478e+04
# Df Residuals:                    1428   BIC:                                  2.482e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
Linear.fittedvalues
# Out:
# 0       16473.283646
# 1       15999.007507
# 2       16440.877249
# 3       16068.317704
# 4       15803.143305
#             ...
# 1430     8757.354297
# 1431     8246.236233
# 1432     8411.306901
# 1433     8541.945900
# 1434    10297.582190
# Length: 1435, dtype: float64

# %%
plt.scatter(Y,Linear.fittedvalues)

# %%
from sklearn.metrics import mean_squared_error

# %%
preds_train=Linear.predict(X_train)

mse_train=mean_squared_error(preds_train,Y_train)
print("The Mean Squared Error for training data :",mse_train)

rmse_train=np.sqrt(mse_train)
print("The Root Mean Squared Error for training data :",rmse_train)
# Out:
# The Mean Squared Error for training data : 1837722.694957484
# The Root Mean Squared Error for training data : 1355.6263109564834

# %%
preds_test=Linear.predict(X_test)

mse_test=mean_squared_error(preds_test,Y_test)
print("The Mean Squared Error for testing data :",mse_test)

rmse_test=np.sqrt(mse_test)
print("The Root Mean Squared Error for testing data :",rmse_test)
# Out:
# The Mean Squared Error for testing data : 1809473.6453898798
# The Root Mean Squared Error for testing data : 1345.1667723334085

# %% [markdown]
# # From the Final Model
# # R-Squared Value is 0.986
# # Hence, It is good model
# # The Mean Square Error of testing data  is less than the training data..
# # It is NOT Overfitting Model

# %% [markdown]
# ##  Lasso Regression Model

# %%
from sklearn.linear_model import Lasso

# %%
lasso=Lasso(alpha=0.2)
lasso.fit(X,Y)
# Out:
# Lasso(alpha=0.2)

# %%
lasso_coeff=lasso.coef_

# %%
lasso_coefficients=pd.DataFrame()
lasso_coefficients['columns']=X.columns
lasso_coefficients['Coefficient_Estimate']=pd.Series(lasso_coeff)
lasso_coefficients
# Out:
#             columns  Coefficient_Estimate
# 0               Age           -123.167116
# 1                KM             -0.017694
# 2                HP             22.227706
# 3             Gears            621.664815
# 4            Weight             20.841256
# 5  Fuel_Type_Diesel            424.535068
# 6  Fuel_Type_Petrol           1101.936100

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='Coefficient_Estimate',y='columns',data=lasso_coefficients)
# Out:
# <Axes: xlabel='Coefficient_Estimate', ylabel='columns'>

# %% [markdown]
# ## Ridge Regression Model

# %%
from sklearn.linear_model import Ridge

ridge=Ridge(alpha=0.6)
ridge.fit(X,Y)
# Out:
# Ridge(alpha=0.6)

# %%
ridge_coeff=ridge.coef_

# %%
ridge_coefficients=pd.DataFrame()
ridge_coefficients['columns']=X.columns
ridge_coefficients['Coefficient_Estimate']=pd.Series(ridge_coeff)
ridge_coefficients
# Out:
#             columns  Coefficient_Estimate
# 0               Age           -123.155637
# 1                KM             -0.017714
# 2                HP             22.247228
# 3             Gears            620.640009
# 4            Weight             20.829375
# 5  Fuel_Type_Diesel            407.370033
# 6  Fuel_Type_Petrol           1081.531781

# %%
plt.figure(figsize=(10,8))
sns.barplot(y='columns',x='Coefficient_Estimate',data=ridge_coefficients)
# Out:
# <Axes: xlabel='Coefficient_Estimate', ylabel='columns'>

# %% [markdown]
# # Interview Questions

# %% [markdown]
# What is Normalization & Standardization and how is it helpful?
# - Normalization and standardization are two essential techniques used in data preprocessing in machine learning and data science. Both techniques are used to transform data into a common scale to make it easier to process and analyze.Normalization and standardization are two essential techniques used in data preprocessing in machine learning and data science. Both techniques are used to transform data into a common scale to make it easier to process and analyze.
# - Standardization:
#    Standardization is a data preprocessing technique used in statistics and machine learning to transform the features of your dataset so that they have a mean of 0 and a standard deviation of 1. This process involves rescaling the distribution of values so that the mean of observed values is aligned to 0 and the standard deviation to 1.
#    - Formula:
#         	Z = (x-mean)/standard deviation
# - Normalization:
#    Normalization in machine learning is a data preprocessing technique used to change the value of the numerical column in the dataset to a common scale without distorting the differences in the range of values or losing information.
#    - Formula:
#             Xnorm = (X - Xmax) / (Xmax - Xmin)

# %% [markdown]
# What techniques can be used to address multicollinearity in multiple linear regression?
#
# - To address multicollinearity, techniques such as regularization or feature selection can be applied to select a subset of independent variables that are not highly correlated with each other
