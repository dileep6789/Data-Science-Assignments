# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('glass.xlsx',sheet_name='glass')
data
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %% [markdown]
# # Data Description:
# # RI : refractive index
# # Na: Sodium (unit measurement: weight percent in corresponding oxide, as are attributes 4-10)
# # Mg: Magnesium
# # AI: Aluminum
# # Si: Silicon
# # K:Potassium
# # Ca: Calcium
# # Ba: Barium
# # Fe: Iron

# %%
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %% [markdown]
# # Type: Type of glass: (class attribute)
# # 1 -- building_windows_float_processed
# # 2 --building_windows_non_float_processed
# # 3 --vehicle_windows_float_processed
# # 4 --vehicle_windows_non_float_processed (none in this database)
# # 5 --containers
# # 6 --tableware
# # 7 --headlamps

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
data.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %% [markdown]
# # Null Values

# %%
data.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %% [markdown]
# # Heat Map

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Duplicate rows

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data[data.duplicated(keep=False)]
# Out:
#          RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 38  1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.0  0.0     1
# 39  1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.0  0.0     1

# %%
df=data.drop_duplicates()
df.reset_index(drop='index',inplace=True)
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 212  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [213 rows x 10 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Differnet Types of Glasses

# %%
print(df['Type'].value_counts())
sns.countplot(df,x='Type',saturation=1)
# Out:
# Type
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: count, dtype: int64
# <Axes: xlabel='Type', ylabel='count'>

# %% [markdown]
# # Pair plots

# %%
sns.pairplot(df.drop('Type',axis=1))

# %%
colors = {1:'red', 2:'blue', 3:'gray',4:"peru",5:"orange",6:"yellow",7:"black"}
sns.pairplot(data,hue="Type",palette=colors)

# %% [markdown]
# # Histograms

# %%
plt.figure(figsize=(10,15))
sns.set_style(style='whitegrid')
for i,column in enumerate(df.columns,1):
    plt.subplot(5,2,i)
    sns.histplot(df[column],kde=True)
    plt.title(f'Distribution of {column}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # The columns [RI,Na,Si,Ca] are almost normally distributed

# %% [markdown]
# # Boxplot

# %%
plt.figure(figsize=(10,15))

for i,column in enumerate(df.columns,1):
    plt.subplot(5,2,i)
    sns.boxplot(df[column],color='peru')
    plt.title(f"box plot of {column}")
    plt.grid(None)
plt.tight_layout()
plt.show()

# %% [markdown]
# # strip plot

# %%
plt.figure(figsize=(10,15))
for i,column in enumerate(df.columns,1):
    plt.subplot(4,3,i)
    sns.stripplot(df[column])
    plt.title(f'strip plot of {column}')
    plt.grid(None)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,15))
for i,column in enumerate(df.columns,1):
    plt.subplot(4,3,i)
    sns.stripplot(data=df,y=df[column],hue='Type',palette=colors)
    plt.title(f'strip plot of {column}')
    plt.grid(None)
plt.tight_layout()
plt.show()

# %%
corr_matrix=df.corr()
corr_matrix
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.198802 -0.127526 -0.400973 -0.539000 -0.287645  0.811183
# Na   -0.198802  1.000000 -0.278420  0.167735 -0.064885 -0.264158 -0.278194
# Mg   -0.127526 -0.278420  1.000000 -0.479575 -0.162437  0.007617 -0.446197
# Al   -0.400973  0.167735 -0.479575  1.000000 -0.016195  0.323683 -0.258068
# Si   -0.539000 -0.064885 -0.162437 -0.016195  1.000000 -0.197281 -0.207145
# K    -0.287645 -0.264158  0.007617  0.323683 -0.197281  1.000000 -0.317032
# Ca    0.811183 -0.278194 -0.446197 -0.258068 -0.207145 -0.317032  1.000000
# Ba    0.001679  0.329080 -0.491818  0.480642 -0.104389 -0.043653 -0.112208
# Fe    0.147083 -0.239374  0.085426 -0.080583 -0.097717 -0.009372  0.126314
# Type -0.160140  0.508837 -0.744195  0.597432  0.147725 -0.012455  0.002677
#
#             Ba        Fe      Type
# RI    0.001679  0.147083 -0.160140
# Na    0.329080 -0.239374  0.508837
# Mg   -0.491818  0.085426 -0.744195
# ...

# %%
plt.figure(figsize=(11,8))

sns.heatmap(corr_matrix,annot=True,fmt='.3f',linewidths=1.0,linecolor='black',cmap='YlGnBu')
# Out:
# <Axes: >

# %% [raw]
# From the above correlation matrix and the heatmap, we can understand that **RI** and **Ca** are strongly correlated.
#
# Other associations such as the features **Na**, **Ba** and **Al** are positively associated with **Type** and the feature **MG**  has a strong negative relation with Type column

# %%
plt.scatter(df['Ca'],df['RI'])

# %% [markdown]
# # Data PreProcessing

# %%
from sklearn.preprocessing import StandardScaler

# %%
std=StandardScaler()
df.iloc[:,:-1]=std.fit_transform(df.iloc[:,:-1])
df
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.879840  0.289558  1.257238 -0.706370 -1.133248 -0.673480 -0.143466
# 1   -0.243816  0.596403  0.639311 -0.180863  0.097037 -0.028962 -0.790201
# 2   -0.716412  0.154546  0.604596  0.182950  0.433746 -0.167073 -0.825349
# 3   -0.227291 -0.238216  0.701798 -0.322346 -0.058368  0.109149 -0.516041
# 4   -0.306608 -0.164573  0.653197 -0.423405  0.550299  0.078457 -0.621487
# ..        ...       ...       ...       ...       ...       ...       ...
# 208 -0.699888  0.903249 -1.860172  2.891336 -0.058368 -0.642789  0.158812
# 209 -0.494986  1.860605 -1.860172  1.092483  0.524398 -0.765554 -0.389506
# 210  0.760865  1.173272 -1.860172  1.153118  0.990612 -0.765554 -0.361387
# 211 -0.607351  1.197820 -1.860172  0.991424  1.236668 -0.765554 -0.333268
# 212 -0.409059  1.013713 -1.860172  1.274389  0.912909 -0.765554 -0.234852
#
#            Ba        Fe  Type
# 0   -0.353808 -0.588301     1
# ...

# %% [markdown]
# # split the data X and Y

# %%
X=df.iloc[:,:-1]
X
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.879840  0.289558  1.257238 -0.706370 -1.133248 -0.673480 -0.143466
# 1   -0.243816  0.596403  0.639311 -0.180863  0.097037 -0.028962 -0.790201
# 2   -0.716412  0.154546  0.604596  0.182950  0.433746 -0.167073 -0.825349
# 3   -0.227291 -0.238216  0.701798 -0.322346 -0.058368  0.109149 -0.516041
# 4   -0.306608 -0.164573  0.653197 -0.423405  0.550299  0.078457 -0.621487
# ..        ...       ...       ...       ...       ...       ...       ...
# 208 -0.699888  0.903249 -1.860172  2.891336 -0.058368 -0.642789  0.158812
# 209 -0.494986  1.860605 -1.860172  1.092483  0.524398 -0.765554 -0.389506
# 210  0.760865  1.173272 -1.860172  1.153118  0.990612 -0.765554 -0.361387
# 211 -0.607351  1.197820 -1.860172  0.991424  1.236668 -0.765554 -0.333268
# 212 -0.409059  1.013713 -1.860172  1.274389  0.912909 -0.765554 -0.234852
#
#            Ba        Fe
# 0   -0.353808 -0.588301
# 1   -0.353808 -0.588301
# ...

# %%
Y=df.iloc[:,-1]
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 208    7
# 209    7
# 210    7
# 211    7
# 212    7
# Name: Type, Length: 213, dtype: int64

# %% [markdown]
# # Dividing the data into train and test split

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score

# %%
train_x,test_x,train_y,test_y=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
print("The Training data shape:")
print(train_x.shape,train_y.shape)
print("The Testing data shape:")
print(test_x.shape,test_y.shape)
# Out:
# The Training data shape:
# (170, 9) (170,)
# The Testing data shape:
# (43, 9) (43,)

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()
model.fit(train_x,train_y)
# Out:
# RandomForestClassifier()

# %%
y_preds=model.predict(test_x)
y_preds
# Out:
# array([7, 1, 2, 5, 1, 2, 1, 2, 2, 2, 1, 2, 2, 2, 2, 7, 2, 2, 3, 3, 2, 7,
#        7, 7, 3, 1, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1, 1, 3, 2, 7, 2, 6, 2],
#       dtype=int64)

# %%
print('The Accuracy of the model is :',accuracy_score(test_y,y_preds))
# Out:
# The Accuracy of the model is : 0.7906976744186046

# %%
print(classification_report(y_preds,test_y))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.78      0.70      0.74        10
#            2       0.89      0.76      0.82        21
#            3       0.50      0.75      0.60         4
#            5       0.50      1.00      0.67         1
#            6       0.50      1.00      0.67         1
#            7       1.00      1.00      1.00         6
#
#     accuracy                           0.79        43
#    macro avg       0.69      0.87      0.75        43
# weighted avg       0.82      0.79      0.80        43

# %% [markdown]
# # when max_feature eual to 3 then the accuracy increases

# %%
model1=RandomForestClassifier(max_features=3,random_state=0)
model1.fit(train_x,train_y)
# Out:
# RandomForestClassifier(max_features=3, random_state=0)

# %%
y_preds1=model1.predict(test_x)
y_preds1
# Out:
# array([7, 1, 2, 5, 1, 2, 1, 2, 2, 2, 1, 1, 2, 2, 2, 7, 2, 2, 3, 1, 6, 7,
#        7, 7, 1, 1, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1, 1, 3, 2, 7, 2, 6, 2],
#       dtype=int64)

# %%
print('The Accuracy of the model1 is :',accuracy_score(test_y,y_preds1))
# Out:
# The Accuracy of the model1 is : 0.7674418604651163

# %%
print(classification_report(y_preds1,test_y))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.78      0.54      0.64        13
#            2       0.83      0.79      0.81        19
#            3       0.33      1.00      0.50         2
#            5       0.50      1.00      0.67         1
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         6
#
#     accuracy                           0.77        43
#    macro avg       0.74      0.89      0.77        43
# weighted avg       0.82      0.77      0.78        43

# %% [markdown]
# # By adding n_estimators=200 then the accuracy also increases

# %%
model2=RandomForestClassifier(n_estimators=200,max_features=3,random_state=0)
model2.fit(train_x,train_y)
# Out:
# RandomForestClassifier(max_features=3, n_estimators=200, random_state=0)

# %%
random_accuracy=model2.score(test_x,test_y)

# %%
y_preds2=model2.predict(test_x)
y_preds2
# Out:
# array([7, 1, 2, 5, 1, 2, 1, 2, 2, 2, 1, 1, 2, 2, 2, 7, 2, 2, 3, 1, 6, 7,
#        7, 7, 2, 1, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1, 1, 3, 2, 7, 2, 6, 2],
#       dtype=int64)

# %%
print('The Accuracy of the model2 is :',accuracy_score(test_y,y_preds2))
# Out:
# The Accuracy of the model2 is : 0.7906976744186046

# %%
print(classification_report(y_preds2,test_y))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.78      0.58      0.67        12
#            2       0.89      0.80      0.84        20
#            3       0.33      1.00      0.50         2
#            5       0.50      1.00      0.67         1
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         6
#
#     accuracy                           0.79        43
#    macro avg       0.75      0.90      0.78        43
# weighted avg       0.84      0.79      0.80        43

# %% [markdown]
# # Bagging and Boosting Ensemble

# %% [markdown]
# # Bagging Ensemble

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
bagging_model=BaggingClassifier(estimator=model2,n_estimators=100,random_state=0)

# %% [markdown]
# # Fitting the Model

# %%
bagging_model.fit(train_x,train_y)
# Out:
# BaggingClassifier(estimator=RandomForestClassifier(max_features=3,
#                                                    n_estimators=200,
#                                                    random_state=0),
#                   n_estimators=100, random_state=0)

# %%
Bagging_accuracy=bagging_model.score(test_x,test_y)

# %%
bag_preds=bagging_model.predict(test_x)
bag_preds
# Out:
# array([7, 1, 1, 5, 1, 2, 1, 2, 2, 2, 1, 1, 2, 2, 2, 7, 2, 2, 3, 2, 7, 7,
#        7, 7, 1, 1, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1, 1, 1, 2, 7, 2, 6, 2],
#       dtype=int64)

# %%
print("The accuracy of the Bagging Model:",accuracy_score(test_y,bag_preds))
# Out:
# The accuracy of the Bagging Model: 0.6976744186046512

# %%
print(classification_report(test_y,bag_preds))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      0.78      0.61         9
#            2       0.74      0.78      0.76        18
#            3       1.00      0.17      0.29         6
#            5       1.00      0.50      0.67         2
#            6       1.00      0.50      0.67         2
#            7       0.86      1.00      0.92         6
#
#     accuracy                           0.70        43
#    macro avg       0.85      0.62      0.65        43
# weighted avg       0.77      0.70      0.67        43

# %% [markdown]
# # Here Estimator is Decision Tree Classifier

# %%
cart=DecisionTreeClassifier()

# %%
bagging_model1=BaggingClassifier(estimator=cart,n_estimators=100,random_state=0)
bagging_model1.fit(train_x,train_y)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=100,
#                   random_state=0)

# %%
bagging_accuracy=bagging_model1.score(test_x,test_y)

# %%
bag_preds1=bagging_model1.predict(test_x)
bag_preds1
# Out:
# array([7, 1, 1, 5, 1, 2, 1, 2, 2, 1, 1, 1, 2, 2, 2, 7, 2, 2, 3, 2, 6, 7,
#        7, 7, 3, 1, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1, 1, 3, 2, 7, 2, 6, 2],
#       dtype=int64)

# %%
print("The accuracy of the Bagging Model:",accuracy_score(test_y,bag_preds1))
# Out:
# The accuracy of the Bagging Model: 0.7209302325581395

# %%
print(classification_report(test_y,bag_preds1))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.54      0.78      0.64         9
#            2       0.72      0.72      0.72        18
#            3       0.67      0.33      0.44         6
#            5       1.00      0.50      0.67         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         6
#
#     accuracy                           0.72        43
#    macro avg       0.82      0.72      0.74        43
# weighted avg       0.74      0.72      0.71        43

# %% [markdown]
# # In second Bagging model the accuracy increased from 0.70 to 0.72

# %% [markdown]
# # Boosting Ensemble

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada_model=AdaBoostClassifier(estimator=RandomForestClassifier(),n_estimators=100,random_state=0)
ada_model.fit(train_x,train_y)
# Out:
# AdaBoostClassifier(estimator=RandomForestClassifier(), n_estimators=100,
#                    random_state=0)

# %%
Boosting_accuracy = ada_model.score(test_x,test_y)

# %%
ada_preds=ada_model.predict(test_x)
ada_preds
# Out:
# array([7, 1, 2, 5, 1, 2, 1, 2, 2, 2, 1, 1, 2, 2, 2, 7, 2, 2, 3, 2, 6, 7,
#        7, 7, 1, 1, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1, 1, 3, 2, 7, 2, 6, 2],
#       dtype=int64)

# %%
print("The Accuaracy Of AdaBoost Model:",accuracy_score(test_y,ada_preds))
# Out:
# The Accuaracy Of AdaBoost Model: 0.7674418604651163

# %%
print(classification_report(test_y,ada_preds))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.58      0.78      0.67         9
#            2       0.75      0.83      0.79        18
#            3       1.00      0.33      0.50         6
#            5       1.00      0.50      0.67         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         6
#
#     accuracy                           0.77        43
#    macro avg       0.89      0.74      0.77        43
# weighted avg       0.81      0.77      0.76        43

# %% [markdown]
# # Stacking Ensemble

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
estimators=[]
model1=DecisionTreeClassifier(random_state=0)
estimators.append(("cart",model1))
model2=LogisticRegression(max_iter=400,random_state=0)
estimators.append(("logistic",model2))
model3=RandomForestClassifier(random_state=0)
estimators.append(('random Forest',model3))

# %%
stack=VotingClassifier(estimators)

# %%
stack.fit(train_x,train_y)
# Out:
# VotingClassifier(estimators=[('cart', DecisionTreeClassifier(random_state=0)),
#                              ('logistic',
#                               LogisticRegression(max_iter=400, random_state=0)),
#                              ('random Forest',
#                               RandomForestClassifier(random_state=0))])

# %%
stacking_accuracy=stack.score(test_x,test_y)

# %%
stack_preds=stack.predict(test_x)
stack_preds
# Out:
# array([7, 1, 2, 5, 1, 2, 1, 2, 2, 1, 1, 1, 2, 2, 2, 7, 2, 2, 1, 1, 1, 7,
#        7, 7, 1, 1, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1, 1, 3, 2, 7, 2, 6, 2],
#       dtype=int64)

# %%
print("The Accuracy of the Stacking is:",accuracy_score(test_y,stack_preds))
# Out:
# The Accuracy of the Stacking is: 0.6976744186046512

# %%
print(classification_report(test_y,stack_preds))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.44      0.78      0.56         9
#            2       0.78      0.78      0.78        18
#            3       1.00      0.17      0.29         6
#            5       1.00      0.50      0.67         2
#            6       1.00      0.50      0.67         2
#            7       1.00      1.00      1.00         6
#
#     accuracy                           0.70        43
#    macro avg       0.87      0.62      0.66        43
# weighted avg       0.79      0.70      0.68        43

# %% [markdown]
# # compare

# %%
Dict={
    "model":["Random Forest","Bagging","Boosting","Stacking"],
    "Accuracy":[random_accuracy,bagging_accuracy,Boosting_accuracy,stacking_accuracy]
}

# %%
dataframe=pd.DataFrame(Dict)
dataframe
# Out:
#            model  Accuracy
# 0  Random Forest  0.790698
# 1        Bagging  0.720930
# 2       Boosting  0.767442
# 3       Stacking  0.697674

# %% [markdown]
# # From 4 models,Random Forest model is getting higher accuracy

# %% [markdown]
# # Additional Notes

# %% [markdown]
# 1. Explain Bagging and Boosting methods. How is it different from each other.
#
# ### Bagging:
#
# - Bagging stands for **Bootstrap Aggregating.**
#
# - It is an ensemble learning technique which uses Bootstrap Aggregation method to build multiple models on random samples and group them together to build a stronger model.
#
# - Examples for bagging are : Bagging Classifier, Random Forest Classifier.
#
#
# ### Boosting:
#
# - Boosting is also an ensemble learning technique which builds multiple models and group them together to form a strong model.
#
# - Some of the examples for Boosting methods are : Adaboost, Gradient Boosting etc.

# %% [markdown]
# *The difference between Bagging and Boosting is as follows:*
#
# - Bagging uses bootstrap method for sampling i.e. it picks random samples from the data (with replacement) and build models on them and ensemble (combine) them all together at the end to create a strong learning model.
#
# - In Boosting, the sampling does not take place randomly, but the sampling will be done based on the results of previous models.
#   First random model is created and if there is any error the sampling will happen again in order to correct the previous error and so on until maximum accuracy / minimum error is achieved.
#
# - In Bagging, the models are built in a parallel manner. That is multiple individual models are built simultaneously and in the end they are grouped together to form a strong model.
#
# - Whereas in Boosting, the models are built one by one, based on previous models.

# %% [markdown]
# 2.Explain how to handle imbalance in the data.
#
# - Imbalance in the data refers to uneven distribution of classes in the target column in the data. Means when one class has higher records and some other class has lower records when compared to other. So this creates bias in the models towards the class which are in majority
#
# - In our case also, the class Type-2 had 76 observations whereas the Type-6 had only 6 records. So this will effect in more bias towards the class Type-2. So in order to avoid these kind of problems it is necessary to handle the imbalance in the data.
#
#
# - *The imbalance in the data can be done by following methods:*
#
#    - **Evaluation Metric :** Choosing the appropriate evaluation metric becomes important when dealing with imbalance data because a high accuracy always does not mean that our model is performing well. We also need to consider other evaluation metrics like: Precision, Recall and F1 score
#
#    - **Sampling methods :** Performing different sampling methods result in adjusting the imbalance. For example we can use undersampling for the classes which are high in number and perform oversampling to create classes which were fewer in number inorder to have that balance between them.
#
#    - **Ensemble Techniques :** Using different ensemble techniques like bagging and boosting helps us to handle the imbalance in the data
